# %%
# for loop
# syntax
# keyword  variable in  collection
#
# 
for data in [1,25,36,14,19]:
    print(data)
# Out:
# 1
# 25
# 36
# 14
# 19

# %%
for character in "we are learning python":
    print(character)
# Out:
# w
# e
#
# a
# r
# e
#
# l
# e
# a
# r
# n
# i
# n
# g
#
# p
# y
# t
# h
# o
# n

# %%
for item in range(1,10):
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
students_name =["ali","ahmad","sana" ,"ayyoub"]
for student_name in students_name:
    print(student_name)
# Out:
# ali
# ahmad
# sana
# ayyoub

# %%
items_list =["book" , "pen" , "bag" , 45,85,96]
for item in items_list:
    print(item)
# Out:
# book
# pen
# bag
# 45
# 85
# 96
