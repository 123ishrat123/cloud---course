# %%
#loop
#keyword condition :
            #body 
#looping types
#1 while loop
#2 for loop
# while loop depend
# counter variable 
# condition
# increment / decrement or chaning in the counter variable

# %%
# while loop


number = 5
while number <10:
         print("loop executing time", number)
         number = number +1
# Out:
# loop executing time 5
# loop executing time 6
# loop executing time 7
# loop executing time 8
# loop executing time 9

# %%
number = 0
while number <10:
         print("loop executing time", number)
         number = number +1
# Out:
# loop executing time 0
# loop executing time 1
# loop executing time 2
# loop executing time 3
# loop executing time 4
# loop executing time 5
# loop executing time 6
# loop executing time 7
# loop executing time 8
# loop executing time 9

# %%
number = 0
while number <=5:
         print("loop executing time", number)
         number = number +1
# Out:
# loop executing time 0
# loop executing time 1
# loop executing time 2
# loop executing time 3
# loop executing time 4
# loop executing time 5

# %%
number = 1
while number != 10: 
         print("loop executing time", number)
         number = number +1
# Out:
# loop executing time 1
# loop executing time 2
# loop executing time 3
# loop executing time 4
# loop executing time 5
# loop executing time 6
# loop executing time 7
# loop executing time 8
# loop executing time 9

# %%
number = 2
while number >= 10:
         print("loop executing time", number)
         number = number +1

# %%
number = 10
while number > 0:
         print("loop executing time", number)
         number = number -1
# Out:
# loop executing time 10
# loop executing time 9
# loop executing time 8
# loop executing time 7
# loop executing time 6
# loop executing time 5
# loop executing time 4
# loop executing time 3
# loop executing time 2
# loop executing time 1

# %%
varibale  = 12
while varibale > 10:
         print("loop executing time", varibale)
         varibale = varibale -1
# Out:
# loop executing time 12
# loop executing time 11
